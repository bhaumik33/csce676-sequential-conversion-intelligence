# %% [markdown]
# # (A) Identification of Candidate Datasets

# %%
# No Code

# %% [markdown]
# 📌 (A) Identification of Candidate Datasets
# Dataset 1: OTTO Recommender Systems Dataset
#
# Source:
# https://www.kaggle.com/datasets/otto/recsys-dataset
#
# Description:
# Large-scale e-commerce session dataset containing user interaction logs (clicks, carts, orders). Each session consists of time-ordered events on items.
#
# Course Topic Alignment
#
# Frequent Itemsets and Association Rule Mining
#
# Clustering (session-based grouping)
#
# Graph Mining (item co-visitation graphs)
#
# Beyond-Course Technique
#
# Sequential Pattern Mining (PrefixSpan, SPADE)
#
# Transformer-based session modeling
#
# Contrastive session embeddings
#
# Dataset Size and Structure
#
# ~12 million sessions
#
# ~220+ million interaction events
#
# JSONL format (each line = one session with list of events)
#
# Data Types
#
# session (int)
#
# aid (item ID, int)
#
# ts (timestamp, milliseconds)
#
# type (categorical: clicks, carts, orders)
#
# Target Variable
#
# No explicit target (unsupervised pattern mining)
#
# Can define supervised task (next item prediction)
#
# Licensing
#
# Public dataset via Kaggle competition terms
#
# Dataset 2: ogbn-products (Open Graph Benchmark)
#
# Source:
# https://ogb.stanford.edu/docs/nodeprop/#ogbn-products
#
# Description:
# Large-scale Amazon product co-purchase graph with node features and category labels.
#
# Course Topic Alignment
#
# Graph Mining
#
# Centrality and community detection
#
# Clustering on node embeddings
#
# Beyond-Course Technique
#
# Graph Neural Networks (GraphSAGE, GAT)
#
# Self-supervised graph representation learning
#
# Dataset Size and Structure
#
# ~2.4 million nodes
#
# ~100+ million edges
#
# 100-dimensional node features
#
# 47 product category labels
#
# Data Types
#
# Node ID
#
# Adjacency edges
#
# Numeric feature vectors
#
# Categorical class label
#
# Target Variable
#
# Multi-class node classification (product category)
#
# Licensing
#
# Public academic benchmark dataset
#
# Dataset 3: CICIDS2017 Intrusion Detection Dataset
#
# Source:
# https://www.unb.ca/cic/datasets/ids-2017.html
#
# Description:
# Network traffic flow dataset with labeled attack types and benign traffic.
#
# Course Topic Alignment
#
# Anomaly Detection
#
# Clustering
#
# Classification
#
# Beyond-Course Technique
#
# Autoencoder-based anomaly detection
#
# Isolation Forest
#
# Deep semi-supervised learning
#
# Dataset Size and Structure
#
# Millions of network flow records
#
# 80+ extracted flow features
#
# CSV format
#
# Data Types
#
# Numeric flow statistics
#
# Categorical attack labels
#
# Target Variable
#
# Binary (attack vs benign)
#
# Multi-class (specific attack types)
#
# Licensing
#
# Public dataset for research purposes (citation required)

# %% [markdown]
# ## Collaboration Declaration – Section (A)
#
# On my honor, I declare the following resources:
#
# 1. Collaborators:
# - None.
#
# 2. Web Sources:
# - https://www.kaggle.com/datasets/otto/recsys-dataset: Dataset description and structure.
# - https://ogb.stanford.edu/docs/nodeprop/#ogbn-products: Dataset details for ogbn-products.
# - https://www.unb.ca/cic/datasets/ids-2017.html: Dataset description for CICIDS2017.
#
# 3. AI Tools:
# - ChatGPT: Assisted in organizing the dataset comparison criteria and structuring the description of candidate datasets. No code was directly copied without verification.
#
# 4. Citations for Papers Used:
# - None.

# %% [markdown]
# # (B) Comparative Analysis of Candidate Datasets

# %%
#No Code

# %% [markdown]
# | Dimension                       | OTTO Recommender Sessions                                                                                                     | ogbn-products Graph                                                                              | CICIDS2017 Network Logs                                                                                        |
# | ------------------------------- | ----------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------ | -------------------------------------------------------------------------------------------------------------- |
# | **Supported Data Mining Tasks** | Course: Frequent itemsets, association rules, clustering. <br> Beyond-course: Sequential pattern mining, session transformers | Course: Graph mining, centrality, community detection. <br> Beyond-course: Graph Neural Networks | Course: Anomaly detection, clustering, classification. <br> Beyond-course: Autoencoder-based anomaly detection |
# | **Data Structure**              | Session-based JSONL with nested event lists                                                                                   | Large-scale graph with node features and edges                                                   | Tabular CSV with flow-level features                                                                           |
# | **Scale**                       | ~12M sessions, 220M+ events                                                                                                   | ~2.4M nodes, 100M+ edges                                                                         | Millions of network flow records                                                                               |
# | **Data Quality Issues**         | Repeated events within sessions, heavy popularity skew, very long sessions                                                    | Class imbalance, graph sparsity in some regions                                                  | Known inconsistencies in flow extraction, potential noisy labels                                               |
# | **Algorithmic Feasibility**     | Apriori may be expensive at full scale but feasible on sampled sessions; sequential mining feasible with pruning              | Full graph GNN training requires high memory; subgraph sampling needed                           | Classical anomaly detection feasible; deep models require scaling strategy                                     |
# | **Bias Considerations**         | Popularity bias, exposure bias, short-session overrepresentation                                                              | Product ecosystem bias, category imbalance                                                       | Synthetic lab traffic may not reflect real-world network diversity                                             |
# | **Ethical Considerations**      | Low risk; anonymized interaction data                                                                                         | Low risk; product-level graph data                                                               | Security dataset; must ensure usage is defensive and research-focused                                          |
# | **Interpretability**            | High interpretability (rules and support metrics are explainable)                                                             | Medium; GNN models less interpretable                                                            | High for classical models; lower for deep anomaly detection                                                    |
# | **Portfolio Strength**          | Strong real-world recommender system relevance                                                                                | Strong ML research benchmark value                                                               | Strong cybersecurity relevance                                                                                 |

# %% [markdown]
# Among the three datasets, OTTO provides the strongest alignment with both course techniques and external sequential modeling methods. It offers interpretable pattern mining opportunities while also enabling exploration of temporal behavior through sequential pattern mining. Additionally, its large-scale real-world structure makes it particularly relevant for recommender system analysis.

# %% [markdown]
# ## Collaboration Declaration – Section (B)
#
# On my honor, I declare the following resources:
#
# 1. Collaborators:
# - None.
#
# 2. Web Sources:
# - None beyond the dataset description pages listed in Section (A).
#
# 3. AI Tools:
# - ChatGPT: Assisted in formatting the comparison table and refining evaluation dimensions (bias, feasibility, ethics).
#
# 4. Citations for Papers Used:
# - None.

# %% [markdown]
#
# # (C) Dataset Selection and Justification

# %%
#No Code

# %% [markdown]
# (C) Dataset Selection and Justification
# Selected Dataset: OTTO Recommender Systems Dataset
#
# After evaluating all three candidate datasets, I selected the OTTO Recommender Systems Dataset for this project.
#
# Reasons for Selection
# 1️⃣ Strong Alignment with Course Techniques
#
# The dataset naturally supports:
#
# Frequent Itemset Mining
#
# Association Rule Mining
#
# Clustering
#
# Potential graph-based co-visitation analysis
#
# Each session can be treated as a transaction basket, making it directly compatible with Apriori or FP-Growth. This allows meaningful exploration of item co-occurrence patterns and support-based rule discovery.
#
# 2️⃣ Clear Opportunity for Beyond-Course Techniques
#
# The dataset contains time-ordered interaction events, which enables:
#
# Sequential Pattern Mining (PrefixSpan, SPADE)
#
# Session-based modeling
#
# Temporal behavioral analysis
#
# This allows comparison between:
#
# Unordered frequent itemsets (course method)
#
# Ordered sequential patterns (external method)
#
# Such comparison provides meaningful analytical depth rather than simply applying multiple unrelated techniques.
#
# 3️⃣ Real-World Relevance and Portfolio Value
#
# The dataset reflects real e-commerce session behavior, including:
#
# Clicks
#
# Carts
#
# Orders
#
# This makes it highly relevant to recommender systems and behavioral modeling, both of which are widely applicable in industry.
#
# 4️⃣ Manageable Ethical Risk
#
# The dataset is anonymized and contains no personally identifiable information. The analysis focuses on aggregated behavioral patterns rather than individual user profiling.
#
# Trade-offs
#
# The dataset is large, requiring sampling strategies for efficient experimentation.
#
# There is no natural text component.
#
# Heavy item popularity skew may bias pattern mining results.
#
# However, these trade-offs also create opportunities to discuss data bias, scalability, and threshold selection.
#
# Final Justification
#
# The OTTO dataset offers the strongest balance between:
#
# Direct applicability of course concepts
#
# Meaningful external technique exploration
#
# Real-world scale considerations
#
# Clear analytical storytelling
#
# For these reasons, it is selected as the primary dataset for this project.

# %% [markdown]
# ## Collaboration Declaration – Section (C)
#
# On my honor, I declare the following resources:
#
# 1. Collaborators:
# - None.
#
# 2. Web Sources:
# - Kaggle OTTO dataset page for structural understanding.
#
# 3. AI Tools:
# - ChatGPT: Assisted in refining justification language and structuring reasoning for dataset selection.
#
# 4. Citations for Papers Used:
# - None.

# %% [markdown]
# # (D) Exploratory Data Analysis (Selected Dataset Only)

# %%
import json
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

# ---------- Config ----------
TRAIN_PATH = Path(r"C:\VS CODE\Sem long\otto-recsys-train.jsonl")
N_SESSIONS = 20_000  # sampling for feasibility

# ---------- Load sample (memory-safe) ----------
sessions = []
with TRAIN_PATH.open("r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        sessions.append(json.loads(line))
        if i + 1 >= N_SESSIONS:
            break

# ---------- Flatten to event-level table ----------
rows = []
for s in sessions:
    sid = s["session"]
    for e in s["events"]:
        rows.append((sid, e["aid"], e["ts"], e["type"]))

df = pd.DataFrame(rows, columns=["session", "aid", "ts", "type"])

# ---------- Basic stats ----------
n_sessions = df["session"].nunique()
n_events = len(df)
n_items = df["aid"].nunique()
event_type_counts = df["type"].value_counts()
event_type_props = df["type"].value_counts(normalize=True)

# ---------- Session length stats ----------
session_lengths = df.groupby("session").size()
session_len_desc = session_lengths.describe()

# ---------- Item popularity stats ----------
item_counts = df["aid"].value_counts()
top1_share = item_counts.head(max(1, int(0.01 * len(item_counts)))).sum() / item_counts.sum()
top10_share = item_counts.head(10).sum() / item_counts.sum()

# ---------- Temporal prep ----------
df["ts"] = pd.to_datetime(df["ts"], unit="ms")
df = df.sort_values(["session", "ts"])

# Compute per-session time span (seconds) and median gap (seconds)
tmp = df.copy()
tmp["dt_sec"] = tmp.groupby("session")["ts"].diff().dt.total_seconds()
median_gap_sec = tmp["dt_sec"].median(skipna=True)

session_span_sec = (df.groupby("session")["ts"].max() - df.groupby("session")["ts"].min()).dt.total_seconds()
span_desc = session_span_sec.describe()

# ---------- Create basket + sequence views (for later techniques) ----------
basket = df.groupby("session")["aid"].apply(lambda x: list(pd.unique(x)))   # unique items, preserves first-seen order
sequence = df.groupby("session")["aid"].apply(list)                        # full ordered sequence with repeats

# ---------- Print a compact report ----------
print("=== OTTO Sample EDA Summary ===")
print(f"Loaded sessions: {len(sessions):,}")
print(f"Event rows: {n_events:,}")
print(f"Unique items: {n_items:,}")

print("\nEvent type counts:")
print(event_type_counts.to_string())

print("\nEvent type proportions:")
print((event_type_props * 100).round(2).astype(str) + "%")

print("\nSession length (events per session) summary:")
print(session_len_desc.to_string())

print("\nSession time span (seconds) summary:")
print(span_desc.to_string())

print(f"\nMedian time gap between consecutive events (sec): {median_gap_sec:.2f}")

print("\nItem popularity concentration:")
print(f"Top 10 items share of all events: {top10_share:.4f}")
print(f"Top 1% items share of all events: {top1_share:.4f}")

# ---------- Plots (3 clean plots) ----------
plt.figure(figsize=(8, 5))
plt.hist(session_lengths, bins=50)
plt.title("Session Length Distribution (events per session)")
plt.xlabel("Events per session")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(10, 5))
item_counts.head(20).plot(kind="bar")
plt.title("Top 20 Items by Event Count")
plt.xlabel("Item (aid)")
plt.ylabel("Event Count")
plt.show()

plt.figure(figsize=(8, 5))
event_type_counts.plot(kind="bar")
plt.title("Event Type Counts")
plt.xlabel("Event Type")
plt.ylabel("Count")
plt.show()
# Out:
# === OTTO Sample EDA Summary ===
# Loaded sessions: 20,000
# Event rows: 1,127,647
# Unique items: 273,569
#
# Event type counts:
# type
# clicks    1027514
# carts       79598
# orders      20535
#
# Event type proportions:
# type
# clicks    91.12%
# carts      7.06%
# orders     1.82%
# Name: proportion, dtype: object
#
# Session length (events per session) summary:
# count    20000.000000
# mean        56.382350
# std         80.902717
# min          2.000000
# 25%          6.000000
# 50%         21.000000
# 75%         69.000000
# max        495.000000
#
# Session time span (seconds) summary:
# count    2.000000e+04
# mean     1.433031e+06
# std      9.010433e+05
# min      9.200000e-02
# 25%      5.061298e+05
# 50%      1.763058e+06
# 75%      2.281730e+06
# max      2.419191e+06
#
# Median time gap between consecutive events (sec): 46.47
#
# Item popularity concentration:
# Top 10 items share of all events: 0.0055
# Top 1% items share of all events: 0.1887

# %% [markdown]
# ## Sampling Justification
#
# I sampled the first **20,000 sessions** from the OTTO training dataset to ensure computational feasibility on a local machine while preserving realistic behavioral patterns.
#
# This sample contains:
#
# - **1,127,647 interaction events**
# - **273,569 unique items**
#
# The sample size is sufficiently large to capture real-world characteristics such as heavy-tailed session behavior and item popularity skew, while remaining manageable for exploratory analysis and algorithm experimentation.
#
# ---
#
# ## Data Quality and Structural Observations
#
# The dataset is structured as session-level interaction logs in JSONL format. Each session contains time-ordered interaction events consisting of:
#
# - Item ID (`aid`)
# - Timestamp (`ts`)
# - Event type (`clicks`, `carts`, `orders`)
#
# The data was flattened into an event-level tabular structure and sorted chronologically within each session to enable both unordered and ordered pattern analysis.
#
# Repeated interactions with the same item occur within sessions, which may influence support counts and require careful treatment when constructing transaction baskets.
#
# ---
#
# ## Event Type Distribution
#
# Interaction types are highly imbalanced:
#
# - **Clicks:** 1,027,514 (91.12%)
# - **Carts:** 79,598 (7.06%)
# - **Orders:** 20,535 (1.82%)
#
# This indicates that purchase intent signals (orders) are sparse relative to browsing activity. Frequent itemset mining based purely on event counts may therefore emphasize browsing behavior rather than purchasing behavior.
#
# ---
#
# ## Session Length Characteristics
#
# Session length distribution is strongly right-skewed:
#
# - **Mean:** 56.38 events
# - **Median:** 21 events
# - **25th percentile:** 6 events
# - **Minimum:** 2 events
#
# Most sessions are short, while a small number of sessions are extremely long (heavy tail). This suggests that a single global support threshold may bias frequent pattern discovery toward high-activity sessions.
#
# ---
#
# ## Item Popularity Concentration
#
# Item frequency analysis reveals moderate concentration:
#
# - Top 10 items account for **0.55%** of all events.
# - Top 1% of items account for **18.87%** of all events.
#
# Although the very top items do not dominate completely, there is clear long-tail behavior. This implies that:
#
# - High support thresholds may mostly capture popular-item co-occurrences.
# - Lower support thresholds may be necessary to uncover niche patterns.
#
# ---
#
# ## Initial Observations Motivating External Techniques
#
# The exploratory analysis reveals three important structural properties:
#
# 1. **Heavy-tailed session behavior** suggests that temporal ordering may contain meaningful behavioral structure beyond simple co-occurrence.
# 2. **Interaction imbalance (91% clicks)** indicates that purchase intent is sparse, motivating analysis beyond raw frequency counts.
# 3. **Moderate popularity concentration** implies that unordered frequent itemsets may primarily reflect exposure-driven associations rather than behavioral sequences.
#
# Because this dataset preserves full temporal ordering of interactions, it is well-suited for comparing:
#
# - **Unordered frequent itemsets and association rules** (course technique)
# - **Sequential pattern mining** (beyond-course technique)
#
# Sequential analysis may reveal progression patterns such as click → cart → order transitions that unordered baskets cannot capture.

# %% [markdown]
# ## Collaboration Declaration – Section (D)
#
# On my honor, I declare the following resources:
#
# 1. Collaborators:
# - None.
#
# 2. Web Sources:
# - https://pandas.pydata.org/docs/: Reference for DataFrame manipulation.
# - https://matplotlib.org/stable/index.html: Reference for plotting histograms and bar charts.
#
# 3. AI Tools:
# - ChatGPT: Assisted in structuring the EDA workflow and refining interpretation of statistical summaries. All code was tested and validated locally before inclusion.
#
# 4. Citations for Papers Used:
# - None.

# %% [markdown]
# # (E) Initial Insights and Project Direction

# %%
#No Code

# %% [markdown]
# ## Key Observations from Exploratory Analysis
# Based on the 20,000-session sample of the OTTO dataset, several structural properties emerge:
#
# ### 1. Heavy-Tailed Session Distribution
# Session lengths are strongly right-skewed. While the median session contains 21 events, some sessions contain hundreds of interactions. This suggests heterogeneous user behavior and raises concerns about bias when applying global support thresholds.
#
# ### 2. Interaction Imbalance
# Clicks represent over 91% of all interactions, while orders account for less than 2%. This indicates that purchase behavior is sparse relative to browsing activity. Mining frequent patterns without considering interaction type may primarily capture browsing co-occurrence rather than purchase intent.
#
# ### 3. Long-Tail Item Distribution
# Although the top 10 items account for only 0.55% of total events, the top 1% of items account for nearly 19% of all interactions. This confirms the presence of long-tail dynamics and moderate popularity concentration.
#
# These characteristics suggest that frequent itemsets may predominantly reflect exposure-driven associations rather than structured behavioral transitions.
#
# ---
#
# ## Hypothesis
#
# High global support thresholds in frequent itemset mining may overlook meaningful but less frequent behavioral sequences.
#
# Specifically:
#
# - Unordered co-occurrence patterns may fail to capture progression behaviors.
# - Temporal ordering may reveal structured interaction flows such as click → cart → order transitions.
# - Sequential patterns may provide stronger behavioral insight than static baskets.
#
# ---
#
# ## Proposed Research Questions
#
# 1. How does varying the minimum support threshold affect the diversity and interpretability of discovered association rules?
#
# 2. To what extent do sequential pattern mining methods reveal behavioral structures that unordered frequent itemsets fail to capture?
#
# 3. Do ordered interaction sequences better distinguish high-intent sessions (those ending in orders) from browsing-only sessions?
#
# ---
#
# ## Project Direction
#
# The project will compare:
#
# - **Frequent itemset mining and association rules** (course technique)
# - **Sequential pattern mining** (beyond-course technique)
#
# The goal is to evaluate whether incorporating temporal structure provides additional explanatory power beyond unordered co-occurrence.
#
# This comparison will help assess the limitations of traditional support-based pattern mining in large-scale e-commerce session data.

# %% [markdown]
# ## Collaboration Declaration – Section (E)
#
# On my honor, I declare the following resources:
#
# 1. Collaborators:
# - None.
#
# 2. Web Sources:
# - None.
#
# 3. AI Tools:
# - ChatGPT: Assisted in refining hypothesis formulation and research question framing based on exploratory findings.
#
# 4. Citations for Papers Used:
# - None.

# %% [markdown]
# GitHub Link: https://github.com/bhaumik33/CSCE-676-600.git
